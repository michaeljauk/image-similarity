# %% [markdown]
# **Some imports**

# %%
import csv
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.dataset import Dataset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import random
import time

# %% [markdown]
# # Global set-up tasks
#
# Following classes or functions will be defined that will be needed for all datasets later

# %% [markdown]
# **Parameters that can be changed in the training methods**
#
# *   Batch Size (when Dataloaders get initialized)
# *   Epochs to train (paramater of train method)
# *   Learning rate to train with (Defined when initializing optimizer)

# %% [markdown]
# ## Siamese Network

# %%
class SiameseNetwork(nn.Module):

    def __init__(self):
        super(SiameseNetwork, self).__init__()

        # Load pre-trained VGG-19; structure: https://images.app.goo.gl/MtYeQkBbpEtGfvQE8
        self.model = torch.hub.load(
            'pytorch/vision:v0.6.0', 'vgg19', pretrained=True)

        # Remove last two FC layers
        self.model.classifier = self.model.classifier[:-6]
        # print(self.model)

    def forward_once(self, x):
        output = self.model(x)
        return output

    def forward(self, x1, x2):
        output1 = self.forward_once(x1)
        output2 = self.forward_once(x2)
        return output1, output2

# %% [markdown]
# ## Constrastive Loss

# %%
class ContrastiveLoss(nn.Module):
    """
    Contrastive loss function; using cosine similarity instead of euclidian distance

    TODO: look if this is right, as the cosine similarity calculates the angel between the two vectors; what we need?

    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=0.5):
        super(ContrastiveLoss, self).__init__()
        self.cosine_similarity = nn.CosineSimilarity()
        self.margin = margin

    def forward(self, output1, output2, label):
        """
        Calculates contrastive loss using cosine similarity though.

        output1: Output 1
        output2: Output 2
        label: Similarity label (1 if genuine, 0 if imposter)
        """

        cos_sim = self.cosine_similarity(output1, output2)
        # euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((label) * torch.pow(cos_sim, 2) +
                                      (1-label) * torch.pow(torch.clamp(self.margin - cos_sim, min=0.0), 2))
        return loss_contrastive

# %% [markdown]
# ## Default Dataset

# %%
class DefaultDataset(Dataset):

    def __init__(self, root_dir, transform=None, should_invert=False):
        self.imageFolderDataset = datasets.ImageFolder(root=root_dir)
        # can be accomplished by self.imageFolderDataset.classes
        # self.categories = [directory for directory in os.listdir(root_dir)]
        self.transform = transform
        self.should_invert = should_invert

    def __getitem__(self, index):
        # TODO: maybe cut out squares of images before transforming them

        # tuple consists of imagepath and index of category/class
        img0_tuple = random.choice(self.imageFolderDataset.imgs)

        same_class = random.randint(0, 1)
        if same_class == 1:
            while True:
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                # Loop until another image of the same class has been found
                if img0_tuple[0] != img1_tuple[0] and img0_tuple[1] == img1_tuple[1]:
                    break
        else:
            while True:
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                # Loop until another image of another class has been found
                if img0_tuple[1] != img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0]).convert("RGB")
        img1 = Image.open(img1_tuple[0]).convert("RGB")

        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)

        return img0, img1, torch.from_numpy(np.array([int(img1_tuple[1] == img0_tuple[1])], dtype=np.float32))

    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Transformations
#
# Transformations that will be used for the train, validation and test dataloaders are defined here. These transforms are ought to be used on any dataset this network is trained with.
#
# The `image_transforms` dict contains all needed transformations.

# %%
image_transforms = {
    'train': transforms.Compose([
              transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
              transforms.RandomRotation(degrees=15),
              transforms.RandomHorizontalFlip(),
              transforms.CenterCrop(size=224),
              transforms.ToTensor(),
              transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
    ]),
    'validation': transforms.Compose([
             transforms.Resize(size=256),
             transforms.CenterCrop(size=224),
             transforms.ToTensor(),
             transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])              
    ]),
    'test': transforms.Compose([
             transforms.Resize(size=256),
             transforms.CenterCrop(size=224),
             transforms.ToTensor(),
             transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])              
    ])
}

# not needed
default_transformations = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
])

# %% [markdown]
# ## Train and Validate method
#
# The following method is to be used to train and validate a network with a single learning rate.

# %%
def hyperparameter_optimization(network, loss_criterion, lr_list, 
                                train_dataloader, validation_dataloader, epochs):
  for lr in lr_list:
    optimizer = optim.Adam(net.parameters(), lr=lr)
    final_network, history = train_and_validate(network, loss_criterion, optimizer, 
                                                train_dataloader, validation_dataloader, epochs)
    torch.save(final_network.state_dict(), f'/content/gdrive/MyDrive/Image Similarity/final_model_lr_{lr}.pth')

def train_and_validate(network, loss_criterion, optimizer,
                       train_dataloader, validation_dataloader, start_epoch, epochs):
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  print(f'Training on device: {device}')
  print('Every 50 mini-batches the runnin loss will be printed')

  lr = optimizer.param_groups[0]['lr']

  history = []
  best_acc = 0.0
  
  cos_similarity = nn.CosineSimilarity()

  for epoch in range(start_epoch, epochs):

    # start time for epoch-statistics
    epoch_start = time.time()

    # print current epoch
    print(f'Epoch : {epoch+1}/{epochs}')
    print(f'Learning Rate : {lr}')

    network.train()

    train_loss = 0.0
    train_acc = 0.0

    running_loss = 0.0

    # train-loop
    for i, data in enumerate(train_dataloader, 0):

      # Load data and move it to gpu if possible
      img0, img1, label = data
      img0 = img0.to(device)
      img1 = img1.to(device)
      label = label.to(device)

      # Clean existing gradients
      optimizer.zero_grad()

      # Forward both images through network
      output1, output2 = network(img0, img1)

      # Compute loss
      loss = loss_criterion(output1, output2, label)

      # Backpropagate
      loss.backward()

      # Update the parameters
      optimizer.step()

      # print stats every 50 mini-batches
      running_loss += loss.data
      if i % 50 == 49:
        # print the average loss of the last 50 predictions
        print(f'  Current loss: {running_loss / 50}')
        # add sum of losses of the last 50 predictions to train_loss
        train_loss += running_loss
        running_loss = 0.0

      # compute train-accuracy
      with torch.no_grad():
        network.eval()
        result = cos_similarity(output1, output2)
        current_acc = torch.zeros([32], dtype=torch.float)
        current_acc = current_acc.to(device)
        for i, label_val in enumerate(label.data):
              if label_val == 0:
                current_acc.data[i] += 1 - result.data[i] 
              else:
                current_acc.data[i] += result.data[i]
        train_acc += current_acc
      network.train()

    # calculate averages and append it to history
    avg_train_loss = train_loss / len(train_dataloader)
    avg_train_acc = train_acc / len(train_dataloader)

    # validation
    avg_valid_acc, avg_valid_loss = computeNetworkAccuracy(network, loss_criterion, validation_dataloader)

    # calculate mean of accuracy tensors
    avg_train_acc = torch.mean(avg_train_acc).item()
    avg_valid_acc = torch.mean(avg_valid_acc).item()

    history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

    epoch_end = time.time()
    
    print(f'Epoch : {epoch}, Training: Loss: {avg_train_loss}, Accuracy: {avg_train_acc*100}%, \n\t\tValidation : Loss : {avg_valid_loss}, Accuracy: {avg_valid_acc*100}%, Time: {epoch_end-epoch_start}s')

    # save if the model has the best acc till now; the saved model with the highest epoch will be the most accurate
    if avg_valid_acc > best_acc:
      best_acc = avg_valid_acc
      torch.save(network.state_dict(), f'/content/gdrive/MyDrive/Image Similarity/model_lr_{lr}_epoch_{epoch}.pth')
    
    torch.save(network.state_dict(), f'/content/gdrive/MyDrive/Image Similarity/model_lr_{lr}_epoch_latest.pth')

  return network, history

def computeNetworkAccuracy(network, criterion, validation_dataloader):
    similarity = nn.CosineSimilarity()
    sum_accuracy = torch.zeros([32], dtype=torch.float)
    sum_loss = 0

    sum_accuracy = sum_accuracy.to(device)

    with torch.no_grad():
        network.eval()
        for i, data in enumerate(validation_dataloader):
            img0, img1, label = data
            img0 = img0.to(device)
            img1 = img1.to(device)
            label = label.to(device)
            x1, x2 = network(img0, img1)
            x1 = x1.to(device)
            x2 = x2.to(device)
            result = similarity(x1, x2)

            for i, label_val in enumerate(label.data):
              if label_val == 0:
                sum_accuracy.data[i] += 1 - result.data[i] 
              else:
                sum_accuracy.data[i] += result.data[i]
            
            sum_loss += criterion(x1, x2, label)

    return sum_accuracy / len(validation_dataloader), sum_loss.data / len(validation_dataloader)

# %% [markdown]
# # Mount Google Drive
#
# Useful for working with large datasets or as a storage for trained networks

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Datasets can now be downloaded to "/content/gdrive/MyDrive"

# %% [markdown]
# ---
#
#
#
# # Set-up Caltech256
#
# Download the Caltech256 dataset

# %% [markdown]
# ## Define Utility methods
# Caltech256 needs to be split up into train, validation and test datasets. In the following methods will be defined, which may accomplish this. The ratio of the split up images will be (75%, 12.5%, 12,5%).

# %%
# imports, may not be needed, but doesn't make a difference 
import numpy as np
import math
from typing import List
import os
import argparse
import glob
import shutil

def get_sub_folder_names(folder):
  sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]
  return sub_folders

def list_files(path):
    files = os.listdir(path)
    return np.asarray(files)

# split files will split caltech256 into train, test and validation datasets
def split_files(oldpath, newpath):
    for name in get_sub_folder_names(oldpath):
        full_dir = os.path.join(os.getcwd(), f"{oldpath}/{name}")

        files = list_files(full_dir)
        total_file = np.size(files,0)
        # We split data set into 3: train, validation and test

        train_size = math.ceil(total_file * 3/4) # 75% for training 

        validation_size = train_size + math.ceil(total_file * 1/8) # 12.5% for validation
        test_size = validation_size + math.ceil(total_file * 1/8) # 12.5x% for testing 

        train = files[0:train_size]
        validation = files[train_size:validation_size]
        test = files[validation_size:]

        move_files(train, full_dir, f"{newpath}/train/{name}")
        move_files(validation, full_dir, f"{newpath}/validation/{name}")
        move_files(test, full_dir, f"{newpath}/test/{name}")

def move_files(files, old_dir, new_dir):
    new_dir = os.path.join(os.getcwd(), new_dir);
    if not os.path.exists(new_dir):
        os.makedirs(new_dir)

    for file in np.nditer(files):
        old_file_path = os.path.join(os.getcwd(), f"{old_dir}/{file}")
        new_file_path = os.path.join(os.getcwd(), f"{new_dir}/{file}")

        shutil.move(old_file_path, new_file_path)

# %% [markdown]
# ## Download Caltech256 with Kaggle
# Download the Caltech256 dataset using kaggle. It will be saved to `./data/caltech256/` or rather `./data/caltech256/256_ObjectCategories`.

# %% [markdown]
# ### Kaggle Initialization

# %%
# !pip install -q kaggle
from google.colab import files

# upload api json from kaggle
files.upload()
# Out:
#      <input type="file" id="files-e46cf9f2-11c7-4f0b-90e7-402230b4399b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e46cf9f2-11c7-4f0b-90e7-402230b4399b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"simonreiterer","key":"06823cea5abaee1e5711eb235c406be9"}'}

# %%
# !mkdir ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# verify that kaggle works
! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              223KB  2021-04-12 07:10:30           2488
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-02-17 16:10:44           1446
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           1067
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52            246
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19            511
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37            368
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04            128
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39             59
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23            228
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00            344
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54             83
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            154
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51             50
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40             40
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54             40
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26             28
# shivamb/netflix-shows                                       Netflix Movies and TV Shows                         1MB  2021-01-18 16:20:26         133276
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         134716
# zynicide/wine-reviews                                       Wine Reviews                                       51MB  2017-11-27 17:08:04         132882
# google/tinyquickdraw                                        QuickDraw Sketches                                 11GB  2018-04-18 19:38:04           2970

# %% [markdown]
# ### Download Caltech256 with Kaggle and split it up

# %%
! kaggle datasets download -d jessicali9530/caltech256
# Out:
# Downloading caltech256.zip to /content
# 100% 2.12G/2.12G [00:50<00:00, 37.6MB/s]
# 100% 2.12G/2.12G [00:50<00:00, 45.0MB/s]

# %%
! mkdir -p ./data/caltech256
! unzip caltech256.zip -d ./data/caltech256
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0077.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0078.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0079.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0080.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0081.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0082.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0083.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0084.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0085.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0086.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0087.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0088.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0089.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0090.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0091.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0092.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0093.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0094.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/228.triceratops/228_0095.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0001.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0002.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0003.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0004.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0005.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0006.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0007.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0008.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0009.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0010.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0011.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0012.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0013.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0014.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0015.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0016.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0017.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0018.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0019.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0020.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0021.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0022.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0023.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0024.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0025.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0026.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0027.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0028.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0029.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0030.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0031.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0032.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0033.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0034.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0035.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0036.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0037.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0038.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0039.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0040.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0041.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0042.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0043.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0044.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0045.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0046.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0047.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0048.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0049.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0050.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0051.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0052.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0053.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0054.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0055.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0056.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0057.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0058.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0059.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0060.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0061.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0062.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0063.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0064.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0065.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0066.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0067.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0068.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0069.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0070.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0071.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0072.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0073.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0074.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0075.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0076.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0077.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0078.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0079.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0080.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0081.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0082.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0083.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0084.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0085.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0086.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0087.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0088.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0089.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0090.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0091.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0092.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0093.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0094.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/229.tricycle/229_0095.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0001.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0002.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0003.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0004.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0005.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0006.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0007.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0008.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0009.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0010.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0011.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0012.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0013.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0014.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0015.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0016.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0017.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0018.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0019.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0020.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0021.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0022.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0023.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0024.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0025.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0026.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0027.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0028.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0029.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0030.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0031.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0032.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0033.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0034.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0035.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0036.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0037.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0038.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0039.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0040.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0041.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0042.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0043.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0044.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0045.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0046.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0047.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0048.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0049.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0050.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0051.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0052.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0053.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0054.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0055.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0056.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0057.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0058.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0059.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0060.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0061.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0062.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0063.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0064.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0065.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0066.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0067.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0068.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0069.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0070.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0071.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0072.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0073.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0074.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0075.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0076.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0077.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0078.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0079.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0080.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0081.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0082.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0083.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0084.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0085.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0086.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0087.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0088.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0089.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0090.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0091.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0092.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0093.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/230.trilobite-101/230_0094.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0001.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0002.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0003.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0004.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0005.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0006.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0007.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0008.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0009.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0010.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0011.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0012.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0013.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0014.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0015.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0016.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0017.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0018.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0019.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0020.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0021.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0022.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0023.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0024.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0025.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0026.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0027.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0028.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0029.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0030.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0031.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0032.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0033.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0034.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0035.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0036.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0037.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0038.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0039.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0040.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0041.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0042.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0043.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0044.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0045.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0046.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0047.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0048.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0049.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0050.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0051.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0052.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0053.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0054.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0055.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0056.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0057.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0058.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0059.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0060.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0061.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0062.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0063.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0064.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0065.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0066.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0067.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0068.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0069.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0070.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0071.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0072.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0073.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0074.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0075.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0076.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0077.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0078.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0079.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0080.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0081.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0082.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0083.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0084.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0085.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0086.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0087.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0088.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0089.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0090.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0091.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0092.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0093.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0094.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0095.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0096.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0097.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0098.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0099.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0100.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0101.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0102.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0103.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0104.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0105.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0106.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0107.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0108.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0109.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0110.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0111.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/231.tripod/231_0112.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0001.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0002.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0003.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0004.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0005.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0006.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0007.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0008.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0009.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0010.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0011.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0012.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0013.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0014.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0015.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0016.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0017.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0018.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0019.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0020.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0021.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0022.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0023.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0024.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0025.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0026.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0027.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0028.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0029.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0030.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0031.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0032.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0033.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0034.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0035.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0036.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0037.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0038.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0039.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0040.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0041.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0042.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0043.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0044.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0045.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0046.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0047.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0048.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0049.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0050.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0051.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0052.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0053.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0054.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0055.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0056.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0057.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0058.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0059.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0060.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0061.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0062.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0063.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0064.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0065.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0066.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0067.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0068.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0069.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0070.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0071.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0072.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0073.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0074.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0075.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0076.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0077.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0078.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0079.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0080.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0081.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0082.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0083.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0084.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0085.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0086.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0087.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0088.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0089.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0090.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0091.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0092.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0093.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0094.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0095.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0096.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0097.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0098.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0099.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0100.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0101.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0102.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0103.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0104.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0105.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0106.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0107.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0108.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0109.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0110.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0111.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0112.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0113.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0114.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0115.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0116.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0117.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0118.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0119.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0120.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0121.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0122.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0123.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0124.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0125.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0126.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0127.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0128.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0129.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0130.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0131.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0132.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0133.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0134.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0135.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0136.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0137.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0138.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0139.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0140.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0141.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0142.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0143.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0144.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0145.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0146.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0147.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0148.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0149.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0150.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0151.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0152.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/232.t-shirt/232_0153.jpg
# ...
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0668.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0669.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0670.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0671.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0672.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0673.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0674.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0675.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0676.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0677.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0678.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0679.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0680.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0681.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0682.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0683.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0684.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0685.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0686.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0687.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0688.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0689.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0690.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0691.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0692.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0693.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0694.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0695.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0696.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0697.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0698.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0699.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0700.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0701.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0702.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0703.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0704.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0705.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0706.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0707.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0708.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0709.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0710.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0711.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0712.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0713.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0714.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0715.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0716.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0717.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0718.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0719.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0720.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0721.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0722.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0723.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0724.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0725.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0726.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0727.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0728.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0729.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0730.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0731.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0732.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0733.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0734.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0735.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0736.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0737.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0738.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0739.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0740.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0741.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0742.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0743.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0744.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0745.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0746.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0747.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0748.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0749.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0750.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0751.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0752.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0753.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0754.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0755.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0756.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0757.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0758.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0759.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0760.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0761.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0762.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0763.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0764.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0765.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0766.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0767.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0768.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0769.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0770.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0771.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0772.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0773.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0774.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0775.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0776.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0777.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0778.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0779.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0780.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0781.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0782.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0783.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0784.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0785.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0786.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0787.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0788.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0789.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0790.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0791.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0792.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0793.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0794.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0795.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0796.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0797.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0798.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0799.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0800.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0801.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0802.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0803.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0804.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0805.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0806.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0807.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0808.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0809.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0810.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0811.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0812.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0813.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0814.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0815.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0816.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0817.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0818.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0819.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0820.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0821.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0822.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0823.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0824.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0825.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0826.jpg
#   inflating: ./data/caltech256/256_objectcategories/256_ObjectCategories/257.clutter/257_0827.jpg

# %%
# remove a directory as the kaggle source contains all images two times
! rm -rf ./data/caltech256/256_objectcategories

# %%
# split caltech256 up into training, test and validation data with a ratio of 75/12.5/12.5
split_files('./data/caltech256/256_ObjectCategories', './data/caltech256_split', )

# %% [markdown]
# ## ~Download Caltech256 from Google Drive~
#
# For some reasons the .tar that is downloaded this way is corrupted. Use Kaggle instead As of: 2021-04-09 12:17

# %%
# download caltech256 using torchvision
caltech256 = torchvision.datasets.Caltech256(
    root = './data/',
    download = True # toggle True/False accordingly
)

# %% [markdown]
# **Either the above or the below**

# %%
# !wget -O './data/caltech256/256_ObjectCategories.tar' http://www.vision.caltech.edu/Image_Datasets/Caltech256/256_ObjectCategories.tar

# !tar -xvf  './data/caltech256/256_ObjectCategories.tar' -C './data/caltech256/'

# %% [markdown]
# Use this to split the files up:

# %%
# split caltech256 up into training, test and validation data with a ratio of 75/12.5/12.5
split_files('./data/caltech256/256_ObjectCategories', './data/caltech256_split', )

# %% [markdown]
# Define siamese network, contrastive loss function

# %% [markdown]
# ## Initialize Caltech256 Datasets
#
# Creates the datasets for the train, validation and test Caltech256 datasets.
#
# The default datasets can be found inside the `caltech_data` dict.

# %%
import torchvision.datasets as datasets
import torch.utils.data as loader

caltech_data = {
    'train': DefaultDataset(root_dir='./data/caltech256_split/train/', transform=image_transforms['train']),
    # 'train': DefaultDataset(root_dir='./data/caltech256_split/train/', transform=default_transformations),
    'validation': DefaultDataset(root_dir='./data/caltech256_split/validation/', transform=image_transforms['validation']),
    'test': DefaultDataset(root_dir='./data/caltech256_split/test/', transform=image_transforms['test'])
}

# %% [markdown]
# # Train with Caltech256

# %% [markdown]
# ## Initialize objects

# %%
# Init network
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = SiameseNetwork()
net.to(device)

# Define epochs to train
num_epochs = 50

# Define learning rate to train with
lr = 0.001

# Init optimizer
optimizer = optim.Adam(net.parameters(), lr=lr)

# Init criterion (Contrastive Loss with Cos-Sim)
criterion = ContrastiveLoss()

# batch size of the dataloaders
batch_size = 32

# create a train dataloader 
train_data = DataLoader(caltech_data['train'], batch_size=batch_size, drop_last=True, shuffle=True)

# create a validation dataloader
validation_data = DataLoader(caltech_data['validation'], batch_size=batch_size, drop_last=True, shuffle=True)

# test datalader not needed here
# test_data = DataLoader(caltech_data['test'], batch_size=batch_size, shuffle=True)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.6.0.zip" to /root/.cache/torch/hub/v0.6.0.zip
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# HBox(children=(FloatProgress(value=0.0, max=574673361.0), HTML(value='')))

# %% [markdown]
# ## Train/validate and save the network

# %%
#net.load_state_dict(torch.load(f'/content/gdrive/MyDrive/Image Similarity/<model>'))
start_epoch = 0 # necessary because colab keeps disconnecting
trained_model, history = train_and_validate(net, criterion, optimizer, train_data, validation_data, start_epoch, num_epochs)
torch.save(trained_model.state_dict(), '/content/gdrive/MyDrive/Image Similarity/final_model.pth')
# Out:
# Training on device: cuda
# Every 50 mini-batches the runnin loss will be printed
# Epoch : 1/50
# Learning Rate : 0.001
#   Current loss: 0.12718749046325684
#   Current loss: 0.12656249105930328
#   Current loss: 0.12671874463558197
#   Current loss: 0.12687499821186066
#   Current loss: 0.1224999949336052
#   Current loss: 0.12578125298023224
#   Current loss: 0.12859374284744263
#   Current loss: 0.12484374642372131
#   Current loss: 0.12296874821186066
#   Current loss: 0.11999999731779099
#   Current loss: 0.12562499940395355
#   Current loss: 0.1237499937415123
#   Current loss: 0.12296874821186066
#   Current loss: 0.12578125298023224
# Epoch : 0, Training: Loss: 0.12153863161802292, Accuracy: 50.0%,
# 		Validation : Loss : 0.1225665882229805, Accuracy: 49.02663826942444%, Time: 1873.3613460063934s
# Epoch : 2/50
# Learning Rate : 0.001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-e69aed8402be> in <module>()
#       1 #net.load_state_dict(torch.load(f'/content/gdrive/MyDrive/Image Similarity/<model>'))
#       2 start_epoch = 0 # necessary because colab keeps disconnecting
# ----> 3 trained_model, history = train_and_validate(net, criterion, optimizer, train_data, validation_data, start_epoch, num_epochs)
#       4 torch.save(trained_model.state_dict(), '/content/gdrive/MyDrive/Image Similarity/final_model.pth')
#
# <ipython-input-25-9ab71a5f90c8> in train_and_validate(network, loss_criterion, optimizer, train_dataloader, validation_dataloader, start_epoch, epochs)
#      55
#      56       # Backpropagate
# ---> 57       loss.backward()
#      58
#      59       # Update the parameters
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:

# %%
print(history)
